# %%
from pathlib import Path
import os

import cv_depot.api as cvd
import numpy as np
import pandas as pd
import torch
from torch import nn

import flatiron
import flatiron.torch.tools as fi_torchtools
from flatiron.core.dataset import Dataset
from flatiron.torch.models.dummy import DummyModel, DummyConfig, DummyPipeline
# Out:
# 2025-02-25 18:44:14.063956: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740509054.080536  258531 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740509054.085693  258531 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-25 18:44:14.103023: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
uri = os.environ.get('SLACK_URI', '')
config = f'''
framework:
    name: torch
    device: cuda
model:
    input_channels: 3
    output_channels: 1
dataset:
    source: /mnt/storage/projects/unet001/dset002/p-unet001_s-dset002_d-glom_v001
    ext_regex: exr
    labels: ['a']
    label_axis: -1
    limit: 1000
    test_size: 0.2
    reshape: False
optimizer:
    name: SGD
loss:
    name: MSELoss
metrics: []
callbacks:
    project: unet001
    root: /mnt/storage/projects
train:
    batch_size: 16
logger:
    slack_url: 'https://hooks.slack.com/services/{uri}'
    slack_channel: dev
    slack_methods:
        - train
    timezone: 'America/Detroit'
'''
import torch._dynamo
torch._dynamo.config.suppress_errors = True
pipe = DummyPipeline \
    .from_string(config) \
    .run()
    # .build() \
    # .compile()
    # .train_test_split() \
    # .train()
# Out:
# WARNING:LogRuntime:BUILD MODEL - Runtime: 0:00:00.001085 (0 seconds)
# WARNING:LogRuntime:COMPILE MODEL - Runtime: 0:00:00.002804 (0 seconds)
# WARNING:LogRuntime:TRAIN TEST SPLIT - Runtime: 0:00:00.028099 (0.03 seconds)
#   0%|          | 0/30 [00:00<?, ?it/s]
# W0225 18:44:29.071000 258531 torch/_dynamo/convert_frame.py:1233] WON'T CONVERT forward /home/ubuntu/flatiron/python/flatiron/torch/models/dummy.py line 20
# W0225 18:44:29.071000 258531 torch/_dynamo/convert_frame.py:1233] due to:
# W0225 18:44:29.071000 258531 torch/_dynamo/convert_frame.py:1233] Traceback (most recent call last):
# W0225 18:44:29.071000 258531 torch/_dynamo/convert_frame.py:1233]   File "/home/ubuntu/pdm/envs/pdm-kVbOHlCT-dev-3.10/lib/python3.10/site-packages/torch/_dynamo/convert_frame.py", line 1164, in __call__
# W0225 18:44:29.071000 258531 torch/_dynamo/convert_frame.py:1233]     result = self._inner_convert(
# ...
