# %% [markdown]
# # Datasets
#
# <font color='#93B6E6'>Datasets consist of a CSV and a directory of sequential files. The CSV lists the filepaths.
#
# <font color='#93B6E6'>The filepaths contain a **frame** field, **f0042** for example.
# <font color='#93B6E6'>At present Datasets support various image formats, such as exr, png, jpeg, as well and npy (numpy chunks).
#
# <font color='#93B6E6'>Dataset.read_csv will read the CSV directly.
#
# <font color='#93B6E6'>Dataset.read_directory will find the CSV file in a given directory.

# %%
import flatiron.api as fi

src = '/mnt/storage/projects/unet001/dset002/p-unet001_s-dset002_d-glom-demo_v001'
data = fi.Dataset.read_directory(src, labels=[3])
data
# Out:
# <Dataset>
#     ASSET_NAME: p-unet001_s-dset002_d-glom_v001
#     ASSET_PATH: /mnt/storage/projects/unet001/dset002/p-unet001_s-dset002_d-glom_v001
#     STATS:
#                     gb  frame  sample
#           min     0.00    0.0     NaN
#           max     0.00   99.0     NaN
#           mean    0.00    NaN     NaN
#           std     0.00    NaN     NaN
#           loaded  0.00    0.0     NaN
#           total   0.01  100.0     NaN

# %% [markdown]
# <font color='#93B6E6'>Calling **\__getitem__** will directly fetch a file of the given index and return it as an cv-depot Image, if it is an image file.

# %%
data[42]
# Out:
# <PIL.Image.Image image mode=RGBA size=1660x674>

# %% [markdown]
# <font color='#93B6E6'>Dataset provide convenient methods for information and access to the underlying file data.

# %%
print('asset_name:', data.asset_name)
print('asset_path:', data.asset_path)
# Out:
# asset_name: p-unet001_s-dset002_d-glom_v001
# asset_path: /mnt/storage/projects/unet001/dset002/p-unet001_s-dset002_d-glom_v001

# %% [markdown]
# <font color='#93B6E6'>**get_filepath** will return the absolute filepath of a given frame. Notice the **f0042** in the file name.

# %%
data.get_filepath(42)
# Out:
# '/mnt/storage/projects/unet001/dset002/p-unet001_s-dset002_d-glom_v001/data/p-unet001_s-dset002_d-glom_v001_f0042.exr'

# %% [markdown]
# <font color='#93B6E6'>**filepaths** provides a full list of filepaths.

# %%
data.filepaths[:3]
# Out:
# ['/mnt/storage/projects/unet001/dset002/p-unet001_s-dset002_d-glom_v001/data/p-unet001_s-dset002_d-glom_v001_f0000.exr',
#  '/mnt/storage/projects/unet001/dset002/p-unet001_s-dset002_d-glom_v001/data/p-unet001_s-dset002_d-glom_v001_f0001.exr',
#  '/mnt/storage/projects/unet001/dset002/p-unet001_s-dset002_d-glom_v001/data/p-unet001_s-dset002_d-glom_v001_f0002.exr']

# %% [markdown]
# <font color='#93B6E6'>**get_arrays** will return the indexed file as a numpy array. If **labels** has been set, then that output will be split accordingly.

# %%
x, y = data.get_arrays(42)
print('x.shape:', x.shape)
print('y.shape:', y.shape)
# Out:
# x.shape: (208, 208, 4)
# y.shape: (208, 208, 1)

# %% [markdown]
# <font color='#93B6E6'>**info** is the central piece of information upon which **Dataset** acts.
# <font color='#93B6E6'>Its information is drawn from the aformentioned CSV.
#
# <font color='#93B6E6'>In this case that CSV only contains the columns asset_path and filepath_relative. The rest are generated.

# %%
data.info
# Out:
#           gb  frame                                         asset_path  \
# 0   0.000127      0  /mnt/storage/projects/unet001/dset002/p-unet00...
# 1   0.000127      1  /mnt/storage/projects/unet001/dset002/p-unet00...
# 2   0.000130      2  /mnt/storage/projects/unet001/dset002/p-unet00...
# 3   0.000124      3  /mnt/storage/projects/unet001/dset002/p-unet00...
# 4   0.000123      4  /mnt/storage/projects/unet001/dset002/p-unet00...
# ..       ...    ...                                                ...
# 95  0.000125     95  /mnt/storage/projects/unet001/dset002/p-unet00...
# 96  0.000114     96  /mnt/storage/projects/unet001/dset002/p-unet00...
# 97  0.000131     97  /mnt/storage/projects/unet001/dset002/p-unet00...
# 98  0.000123     98  /mnt/storage/projects/unet001/dset002/p-unet00...
# 99  0.000127     99  /mnt/storage/projects/unet001/dset002/p-unet00...
#
#                                  filepath_relative  \
# 0   data/p-unet001_s-dset002_d-glom_v001_f0000.exr
# 1   data/p-unet001_s-dset002_d-glom_v001_f0001.exr
# 2   data/p-unet001_s-dset002_d-glom_v001_f0002.exr
# 3   data/p-unet001_s-dset002_d-glom_v001_f0003.exr
# 4   data/p-unet001_s-dset002_d-glom_v001_f0004.exr
# ..                                             ...
# 95  data/p-unet001_s-dset002_d-glom_v001_f0095.exr
# 96  data/p-unet001_s-dset002_d-glom_v001_f0096.exr
# 97  data/p-unet001_s-dset002_d-glom_v001_f0097.exr
# 98  data/p-unet001_s-dset002_d-glom_v001_f0098.exr
# 99  data/p-unet001_s-dset002_d-glom_v001_f0099.exr
#
#                                              filepath  loaded
# 0   /mnt/storage/projects/unet001/dset002/p-unet00...   False
# 1   /mnt/storage/projects/unet001/dset002/p-unet00...   False
# 2   /mnt/storage/projects/unet001/dset002/p-unet00...   False
# 3   /mnt/storage/projects/unet001/dset002/p-unet00...   False
# 4   /mnt/storage/projects/unet001/dset002/p-unet00...   False
# ..                                                ...     ...
# 95  /mnt/storage/projects/unet001/dset002/p-unet00...   False
# 96  /mnt/storage/projects/unet001/dset002/p-unet00...   False
# 97  /mnt/storage/projects/unet001/dset002/p-unet00...   False
# 98  /mnt/storage/projects/unet001/dset002/p-unet00...   False
# 99  /mnt/storage/projects/unet001/dset002/p-unet00...   False
#
# [100 rows x 6 columns]

# %% [markdown]
# <font color='#93B6E6'>**Load** 50 images from the dataset into memory.
#
# <font color='#93B6E6'>For general workflows, especially Torch dataloaders, it is not necessary to load data. Datasets simply load on request with **\__getitem__**.

# %%
data.load(limit=50, shuffle=True)
# Out:
# May not total to 100% - Loading Dataset Files:   0%|          | 0/100 [00:00<?, ?it/s]
# <Dataset>
#     ASSET_NAME: p-unet001_s-dset002_d-glom_v001
#     ASSET_PATH: /mnt/storage/projects/unet001/dset002/p-unet001_s-dset002_d-glom_v001
#     STATS:
#                     gb  frame  sample
#           min     0.00    0.0     NaN
#           max     0.00   99.0     NaN
#           mean    0.00    NaN     0.0
#           std     0.00    NaN     NaN
#           loaded  0.02   50.0    50.0
#           total   0.01  100.0    36.0

# %% [markdown]
# <font color='#93B6E6'>Notice that some rows now have a True value under the loaded column, such as frame 99.

# %%
data.info
# Out:
#           gb  frame                                         asset_path  \
# 0   0.000127      0  /mnt/storage/projects/unet001/dset002/p-unet00...
# 1   0.000127      1  /mnt/storage/projects/unet001/dset002/p-unet00...
# 2   0.000130      2  /mnt/storage/projects/unet001/dset002/p-unet00...
# 3   0.000124      3  /mnt/storage/projects/unet001/dset002/p-unet00...
# 4   0.000123      4  /mnt/storage/projects/unet001/dset002/p-unet00...
# ..       ...    ...                                                ...
# 95  0.000125     95  /mnt/storage/projects/unet001/dset002/p-unet00...
# 96  0.000114     96  /mnt/storage/projects/unet001/dset002/p-unet00...
# 97  0.000131     97  /mnt/storage/projects/unet001/dset002/p-unet00...
# 98  0.000123     98  /mnt/storage/projects/unet001/dset002/p-unet00...
# 99  0.000127     99  /mnt/storage/projects/unet001/dset002/p-unet00...
#
#                                  filepath_relative  \
# 0   data/p-unet001_s-dset002_d-glom_v001_f0000.exr
# 1   data/p-unet001_s-dset002_d-glom_v001_f0001.exr
# 2   data/p-unet001_s-dset002_d-glom_v001_f0002.exr
# 3   data/p-unet001_s-dset002_d-glom_v001_f0003.exr
# 4   data/p-unet001_s-dset002_d-glom_v001_f0004.exr
# ..                                             ...
# 95  data/p-unet001_s-dset002_d-glom_v001_f0095.exr
# 96  data/p-unet001_s-dset002_d-glom_v001_f0096.exr
# 97  data/p-unet001_s-dset002_d-glom_v001_f0097.exr
# 98  data/p-unet001_s-dset002_d-glom_v001_f0098.exr
# 99  data/p-unet001_s-dset002_d-glom_v001_f0099.exr
#
#                                              filepath  loaded
# 0   /mnt/storage/projects/unet001/dset002/p-unet00...    True
# 1   /mnt/storage/projects/unet001/dset002/p-unet00...   False
# 2   /mnt/storage/projects/unet001/dset002/p-unet00...    True
# 3   /mnt/storage/projects/unet001/dset002/p-unet00...   False
# 4   /mnt/storage/projects/unet001/dset002/p-unet00...   False
# ..                                                ...     ...
# 95  /mnt/storage/projects/unet001/dset002/p-unet00...   False
# 96  /mnt/storage/projects/unet001/dset002/p-unet00...   False
# 97  /mnt/storage/projects/unet001/dset002/p-unet00...   False
# 98  /mnt/storage/projects/unet001/dset002/p-unet00...    True
# 99  /mnt/storage/projects/unet001/dset002/p-unet00...    True
#
# [100 rows x 6 columns]

# %% [markdown]
# <font color='#93B6E6'>The loaded and gb portions of the stats dataframe have changed as well

# %%
data.stats
# Out:
#           gb  frame  sample
# min     0.00    0.0     NaN
# max     0.00   99.0     NaN
# mean    0.00    NaN     0.0
# std     0.00    NaN     NaN
# loaded  0.02   50.0    50.0
# total   0.01  100.0    36.0

# %% [markdown]
# <font color='#93B6E6'>Calling **load** compiled 50 images into a single numpy array, which is accessed through the **data** member.

# %%
data.data.shape
# Out:
# (50, 208, 208, 4)

# %% [markdown]
# <font color='#93B6E6'>We handed in a label axis and index when we constructed the Dataset.
# <font color='#93B6E6'>A label of [3] here is to the alpha channel (of axis -1).
#
# <font color='#93B6E6'>This information allows us to split **.data** into x and y arrays, using **.xy_split()**
#
# <font color='#93B6E6'>**xy_split** requires **load** to have been called.

# %%
x, y = data.xy_split()
print('    labels:', data.labels)
print('label_axis:', data.label_axis)
print('   y.shape:', y.shape)
print('   x.shape:', x.shape)
# Out:
#     labels: [3]
# label_axis: -1
#    y.shape: (50, 208, 208, 1)
#    x.shape: (50, 208, 208, 3)

# %% [markdown]
# <font color='#93B6E6'>**unload** simply deletes the **data** member from memory.

# %%
data.unload()
# Out:
# <Dataset>
#     ASSET_NAME: p-unet001_s-dset002_d-glom_v001
#     ASSET_PATH: /mnt/storage/projects/unet001/dset002/p-unet001_s-dset002_d-glom_v001
#     STATS:
#                     gb  frame  sample
#           min     0.00    0.0     NaN
#           max     0.00   99.0     NaN
#           mean    0.00    NaN     NaN
#           std     0.00    NaN     NaN
#           loaded  0.00    0.0     NaN
#           total   0.01  100.0     NaN

# %% [markdown]
# <font color='#93B6E6'>**train_test_split** will split the dataset into train and test dataset according to the labels and label axis.

# %%
train, test = data.train_test_split(test_size=0.2, shuffle=True, seed=42)
print('train shape:', train.info.shape)
print(' test shape:', test.info.shape)
# Out:
# train shape: (80, 6)
#  test shape: (20, 6)

# %% [markdown]
# <font color='#93B6E6'>You can call **.load.xy_split()** on train and test as needed.

# %%
train_x, train_y = train.load().xy_split()
print('train_x shape:', train_x.shape)
print('train_y shape:', train_y.shape)
# Out:
# Loading Dataset Files:   0%|          | 0/80 [00:00<?, ?it/s]
# train_x shape: (80, 208, 208, 3)
# train_y shape: (80, 208, 208, 1)

# %% [markdown]
# ---
# # MultiDatasets
#
# <font color='#93B6E6'>MultiDatasets are a class for combining Datasets of the same length.
# <font color='#93B6E6'>Dataset can consist of completely different file types.

# %%
multi = fi.MultiDataset(dict(base=data, additional=data))
multi.info
# Out:
#     frame                                filepath_additional  \
# 0       0  /mnt/storage/projects/unet001/dset002/p-unet00...
# 1       1  /mnt/storage/projects/unet001/dset002/p-unet00...
# 2       2  /mnt/storage/projects/unet001/dset002/p-unet00...
# 3       3  /mnt/storage/projects/unet001/dset002/p-unet00...
# 4       4  /mnt/storage/projects/unet001/dset002/p-unet00...
# ..    ...                                                ...
# 95     95  /mnt/storage/projects/unet001/dset002/p-unet00...
# 96     96  /mnt/storage/projects/unet001/dset002/p-unet00...
# 97     97  /mnt/storage/projects/unet001/dset002/p-unet00...
# 98     98  /mnt/storage/projects/unet001/dset002/p-unet00...
# 99     99  /mnt/storage/projects/unet001/dset002/p-unet00...
#
#                                         filepath_base
# 0   /mnt/storage/projects/unet001/dset002/p-unet00...
# 1   /mnt/storage/projects/unet001/dset002/p-unet00...
# 2   /mnt/storage/projects/unet001/dset002/p-unet00...
# 3   /mnt/storage/projects/unet001/dset002/p-unet00...
# 4   /mnt/storage/projects/unet001/dset002/p-unet00...
# ..                                                ...
# 95  /mnt/storage/projects/unet001/dset002/p-unet00...
# 96  /mnt/storage/projects/unet001/dset002/p-unet00...
# 97  /mnt/storage/projects/unet001/dset002/p-unet00...
# 98  /mnt/storage/projects/unet001/dset002/p-unet00...
# 99  /mnt/storage/projects/unet001/dset002/p-unet00...
#
# [100 rows x 3 columns]

# %%
multi[2]
# Out:
# {'base': <cv_depot.core.image.Image at 0x7fa2d7b70430>,
#  'additional': <cv_depot.core.image.Image at 0x7fa2d7b83280>}

# %%
multi[2]['additional']
# Out:
# <PIL.Image.Image image mode=RGBA size=1668x408>
